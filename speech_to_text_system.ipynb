# %%
# ✅ Install required libraries
# !pip install SpeechRecognition --quiet
# !pip install pydub --quiet

# ✅ Import libraries
import speech_recognition as sr
from pydub import AudioSegment
from pydub.playback import play
import os

# ✅ Convert MP3 or other formats to WAV (optional)
# If your input is already in WAV format, skip this step.
# audio = AudioSegment.from_mp3("sample_audio.mp3")
# audio.export("converted_audio.wav", format="wav")

# ✅ Initialize recognizer
recognizer = sr.Recognizer()

# ✅ Load audio file (make sure the file is uploaded)
AUDIO_FILE = "sample.wav"  # Change this to your file name

# ✅ Transcribe audio
with sr.AudioFile(AUDIO_FILE) as source:
    audio_data = recognizer.record(source)
    try:
        text = recognizer.recognize_google(audio_data)
        print("Recognized Speech:")
        print(text)
    except sr.UnknownValueError:
        print("Speech Recognition could not understand the audio.")
    except sr.RequestError as e:
        print("Could not request results; {0}".format(e))
